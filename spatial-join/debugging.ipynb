# %%
from coiled.v2 import Cluster

cluster = Cluster(
    name="spatial-join",
    software="coiled-examples/spatial-join",
    n_workers=50,
    worker_memory="16Gib",
)
# Out:
# ╭───────────────────────────────────────── Coiled Cluster ─────────────────────────────────────────╮
# │                     ]8;id=189213;https://cloud.coiled.io/rrpelgrim/clusters/27463/details\https://cloud.coiled.io/rrpelgrim/clusters/27463/details]8;;\                     │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────── Overview ───────────────────╮╭──────────────── Configuration ─────────────────╮
# │                                                ││                                                │
# │ Cluster Name: spatial-join                     ││ Region: us-east-1                              │
# │                                                ││                                                │
# │ Cluster Status: scaling ..                     ││ Scheduler Instance Type: t3.medium             │
# │                                                ││                                                │
# │ Scheduler Status: started                      ││ Worker Instance Type(s): t3a.xlarge (50)       │
# │                                                ││                                                │
# │ Dashboard Address: ]8;id=403979;http://3.239.60.122:8787\http://3.239.60.122:8787]8;;\    ││ Workers Requested: 50                          │
# │                                                ││                                                │
# │                                                ││                                                │
# ╰────────────────────────────────────────────────╯╰────────────────────────────────────────────────╯
# ╭─────────────────────────────────── (2022/05/12 15:09:57 CEST) ───────────────────────────────────╮
# │                                                                                                  │
# │                    Most of your workers have arrived. Cluster ready for use.                     │
# │                                                                                                  │
# │                                                                                                  │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
from distributed import Client
client = Client(cluster)

# %%
import dask.dataframe as dd

ddf = dd.read_parquet(
    "s3://coiled-datasets/dask-book/nyc-tlc/2009-2013/*",
    engine="pyarrow",
    storage_options={"anon": True},
)

# %%
ddf.isna().sum().compute()
# Out:
# vendor_id            0
# pickup_datetime      0
# dropoff_datetime     0
# passenger_count      0
# trip_distance        0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# payment_type         0
# fare_amount          0
# surcharge            0
# tip_amount           0
# tolls_amount         0
# total_amount         0
# dtype: int64

# %%
ddf.dtypes
# Out:
# vendor_id                    object
# pickup_datetime      datetime64[ns]
# dropoff_datetime     datetime64[ns]
# passenger_count               int64
# trip_distance               float64
# pickup_longitude            float64
# pickup_latitude             float64
# dropoff_longitude           float64
# dropoff_latitude            float64
# payment_type                 object
# fare_amount                 float64
# surcharge                   float64
# tip_amount                  float64
# tolls_amount                float64
# total_amount                float64
# dtype: object

# %%
import dask_geopandas

ddf = ddf.set_geometry(
    dask_geopandas.points_from_xy(ddf, "pickup_longitude", "pickup_latitude"),
)

# %%
ddf = ddf.set_crs(4326)

# %%
ddf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
import geopandas as gpd

ngbhoods = gpd.read_file(
    "CHS_2009_DOHMH_2010B/CHS_2009_DOHMH_2010B.shp"
)
ngbhoods = ngbhoods[["FIRST_UHF_", "UHF_CODE", "geometry"]]
ngbhoods = ngbhoods[:34]
ngbhoods = ngbhoods.rename(columns={"FIRST_UHF_": "nhbd_name", "UHF_CODE": "nhbd_id"})
ngbhoods = ngbhoods.to_crs(epsg=4326)

ngbhoods.head(3)
# Out:
#                  nhbd_name  nhbd_id  \
# 0  Kingsbridge - Riverdale    101.0
# 1          Northeast Bronx    102.0
# 2     Fordham - Bronx Park    103.0
#
#                                             geometry
# 0  POLYGON ((-73.87793 40.90556, -73.87859 40.903...
# 1  POLYGON ((-73.85253 40.90985, -73.85235 40.909...
# 2  POLYGON ((-73.85627 40.88315, -73.85666 40.882...

# %%
dd.from_pandas(ngbhoods, npartitions=1).compute()
# Out:
#                                nhbd_name      nhbd_id  \
# 0                Kingsbridge - Riverdale        101.0
# 1                        Northeast Bronx        102.0
# 2                   Fordham - Bronx Park        103.0
# 3                   Pelham - Throgs Neck        104.0
# 4                             Greenpoint        201.0
# 5            Downtown  - Heights - Slope        202.0
# 6     Bedford Stuyvesant - Crown Heights        203.0
# 7                          East New York        204.0
# 8                            Sunset Park        205.0
# 9                           Borough Park        206.0
# 10              East Flatbush - Flatbush        207.0
# 11                  Canarsie - Flatlands        208.0
# 12               Bensonhurst - Bay Ridge        209.0
# 13         Coney Island - Sheepshead Bay        210.0
# 14               Williamsburg - Bushwick        211.0
# 15           Washington Heights - Inwood        301.0
# 16  Central Harlem - Morningside Heights        302.0
# 17                           East Harlem        303.0
# 18                       Upper West Side        304.0
# 19            Long Island City - Astoria        401.0
# 20                           West Queens        402.0
# 21                  Flushing - Clearview        403.0
# 22              Ridgewood - Forest Hills        405.0
# 23                      Southwest Queens        407.0
# 24                               Jamaica        408.0
# 25                      Southeast Queens        409.0
# 26                              Rockaway        410.0
# 27            Upper East Side - Gramercy     305307.0
# 28                     Chelsea - Village     306308.0
# 29         Union Square, Lower Manhattan     309310.0
# 30                     Bayside - Meadows     404406.0
# 31                           Northern SI     501502.0
# 32                           Southern SI     503504.0
# 33                           South Bronx  105106107.0
#
#                                              geometry
# 0   POLYGON ((-73.87793 40.90556, -73.87859 40.903...
# 1   POLYGON ((-73.85253 40.90985, -73.85235 40.909...
# 2   POLYGON ((-73.85627 40.88315, -73.85666 40.882...
# 3   MULTIPOLYGON (((-73.81625 40.86082, -73.81584 ...
# 4   POLYGON ((-73.92436 40.71557, -73.92404 40.714...
# 5   POLYGON ((-73.97022 40.70673, -73.97018 40.704...
# 6   POLYGON ((-73.94506 40.68910, -73.94491 40.688...
# 7   POLYGON ((-73.86651 40.68447, -73.86630 40.683...
# 8   MULTIPOLYGON (((-73.99723 40.66921, -73.99687 ...
# 9   POLYGON ((-73.97379 40.65639, -73.97355 40.655...
# 10  POLYGON ((-73.96290 40.66380, -73.96243 40.663...
# 11  MULTIPOLYGON (((-73.89860 40.65583, -73.89800 ...
# 12  POLYGON ((-74.01695 40.63056, -74.01729 40.629...
# 13  POLYGON ((-73.93935 40.61019, -73.93754 40.608...
# 14  POLYGON ((-73.92633 40.71404, -73.92453 40.713...
# 15  MULTIPOLYGON (((-73.92255 40.87757, -73.92187 ...
# 16  POLYGON ((-73.93431 40.82431, -73.93409 40.820...
# 17  MULTIPOLYGON (((-73.93672 40.80822, -73.93511 ...
# 18  POLYGON ((-73.96485 40.80671, -73.96201 40.805...
# 19  POLYGON ((-73.90387 40.77891, -73.90347 40.778...
# 20  MULTIPOLYGON (((-73.88806 40.76831, -73.88773 ...
# 21  MULTIPOLYGON (((-73.81985 40.80089, -73.81307 ...
# 22  POLYGON ((-73.84418 40.73426, -73.84397 40.733...
# 23  MULTIPOLYGON (((-73.82574 40.71517, -73.82464 ...
# 24  MULTIPOLYGON (((-73.74925 40.70293, -73.74895 ...
# 25  POLYGON ((-73.71345 40.75961, -73.71331 40.759...
# 26  MULTIPOLYGON (((-73.76702 40.61422, -73.76520 ...
# 27  MULTIPOLYGON (((-73.96389 40.75209, -73.96717 ...
# 28  POLYGON ((-73.99334 40.77273, -73.99065 40.771...
# 29  MULTIPOLYGON (((-73.98977 40.73918, -73.98771 ...
# 30  POLYGON ((-73.73499 40.77303, -73.73399 40.772...
# 31  POLYGON ((-74.07793 40.64902, -74.07627 40.648...
# 32  MULTIPOLYGON (((-74.17855 40.62466, -74.17851 ...
# 33  POLYGON ((-73.91444 40.85978, -73.91328 40.859...

# %%
# %%time
joined1 = ddf.sjoin(ngbhoods, predicate="within")
# Out:
# CPU times: user 25.4 ms, sys: 3.36 ms, total: 28.8 ms
# Wall time: 26.7 ms

# %%
joined1.head()
# Out:
# distributed.protocol.core - CRITICAL - Failed to Serialize
# Traceback (most recent call last):
#   File "/Users/rpelgrim/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/distributed/protocol/core.py", line 76, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#   File "/Users/rpelgrim/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/msgpack/__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#   File "msgpack/_packer.pyx", line 294, in msgpack._cmsgpack.Packer.pack
#   File "msgpack/_packer.pyx", line 300, in msgpack._cmsgpack.Packer.pack
#   File "msgpack/_packer.pyx", line 297, in msgpack._cmsgpack.Packer.pack
#   File "msgpack/_packer.pyx", line 264, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 231, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 231, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 264, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 231, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 231, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 231, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 264, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 264, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 291, in msgpack._cmsgpack.Packer._pack
# TypeError: can not serialize 'numpy.int64' object
# distributed.comm.utils - INFO - Unserializable Message: [{'op': 'update-graph-hlg', 'hlg': {'layers': [{'__module__': 'dask.blockwise', '__name__': 'Blockwise', 'state': {'output': '_set_crs-6ca0659b532951365eb2f3c74d7d5dda', 'output_indices': ('.0',), 'func': b'\x80\x04\x95\x03\x00\x01\x00\x00\x00\x00\x00\x8c\x11dask.optimization\x94\x8c\x10SubgraphCallable\x94\x93\x94(}\x94(\x8c)_set_crs-6ca0659b532951365eb2f3c74d7d5dda\x94\x8cEpoints_from_xy-set_geometry-_set_crs-6ca0659b532951365eb2f3c74d7d5dda\x94\x8c0read-parquet-520df5ddd4d8ac310c949ff50485dcbb_.0\x94\x8c\x1edask.dataframe.io.parquet.core\x94\x8c\x16ParquetFunctionWrapper\x94\x93\x94)\x81\x94}\x94(\x8c\x06engine\x94\x8c\x1fdask.dataframe.io.parquet.arrow\x94\x8c\x12ArrowDatasetEngine\x94\x93\x94\x8c\x02fs\x94\x8c\x0bfsspec.spec\x94\x8c\rmake_instance\x94\x93\x94\x8c\ts3fs.core\x94\x8c\x0cS3FileSystem\x94\x93\x94)}\x94\x8c\x04anon\x94\x88s\x87\x94R\x94\x8c\x04meta\x94\x8c\x11pandas.core.frame\x94\x8c\tDataFrame\x94\x93\x94)\x81\x94}\x94(\x8c\x04_mgr\x94\x8c\x1epandas.core.internals.managers\x94\x8c\x0cBlockManager\x94\x93\x94(\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94\x8c\x1cpandas.core.internals.blocks\x94\x8c\tnew_block\x94\x93\x94\x85\x94R\x94(h*)}\x94\x8c\x04ndim\x94K\x02sNt\x94b\x8c\x15numpy.core.multiarray\x94\x8c\x0c_reconstruct\x94\x93\x94\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94K\x00\x85\x94C\x01b\x94\x87\x94R\x94(K\x01K\x02K\x00\x86\x94h3\x8c\x05dtype\x94\x93\x94\x8c\x02O8\x94\x89\x88\x87\x94R\x94(K\x03\x8c\x01|\x94NNNJ\xff\xff\xff\xffJ\xff\xff\xff\xffK?t\x94b\x89]\x94t\x94b\x8c\x08builtins\x94\x8c\x05slice\x94\x93\x94K\x00K\x12K\t\x87\x94R\x94\x86\x94R\x94h\'h*\x85\x94R\x94(h*)}\x94h.K\x02sNt\x94b\x8c\x13pandas._libs.arrays\x94\x8c\x1c__pyx_unpickle_NDArrayBacked\x94\x93\x94\x8c\x1cpandas.core.arrays.datetimes\x94\x8c\rDatetimeArray\x94\x93\x94J\xb8\\U\rN\x87\x94R\x94h<\x8c\x02M8\x94\x89\x88\x87\x94R\x94(K\x04\x8c\x01<\x94NNNJ\xff\xff\xff\xffJ\xff\xff\xff\xffK\x00}\x94(C\x02ns\x94K\x01K\x01K\x01t\x94\x86\x94t\x94bh2h5K\x00\x85\x94h7\x87\x94R\x94(K\x01K\x02K\x00\x86\x94hY\x89C\x00\x94t\x94b}\x94\x87\x94bhFK\x01K\x03K\x01\x87\x94R\x94\x86\x94R\x94h\'h*\x85\x94R\x94(h*)}\x94h.K\x02sNt\x94bh2h5K\x00\x85\x94h7\x87\x94R\x94(K\x01K\x01K\x00\x86\x94h<\x8c\x02i8\x94\x89\x88\x87\x94R\x94(K\x03hZNNNJ\xff\xff\xff\xffJ\xff\xff\xff\xffK\x00t\x94b\x89hdt\x94bhFK\x03K\x04K\x01\x87\x94R\x94\x86\x94R\x94h\'h*\x85\x94R\x94(h*)}\x94h.K\x02sNt\x94bh2h5K\x00\x85\x94h7\x87\x94R\x94(K\x01K\nK\x00\x86\x94h<\x8c\x02f8\x94\x89\x88\x87\x94R\x94(K\x03hZNNNJ\xff\xff\xff\xffJ\xff\xff\xff\xffK\x00t\x94b\x89hdt\x94bh2h5K\x00\x85\x94h7\x87\x94R\x94(K\x01K\n\x85\x94hv\x89CP\x04\x00\x00\x00\x00\x00\x00\x00\x05\x00\x00\x00\x00\x00\x00\x00\x06\x00\x00\x00\x00\x00\x00\x00\x07\x00\x00\x00\x00\x00\x00\x00\x08\x00\x00\x00\x00\x00\x00\x00\n\x00\x00\x00\x00\x00\x00\x00\x0b\x00\x00\x00\x00\x00\x00\x00\x0c\x00\x00\x00\x00\x00\x00\x00\r\x00\x00\x00\x00\x00\x00\x00\x0e\x00\x00\x00\x00\x00\x00\x00\x94t\x94b\x86\x94R\x94t\x94]\x94(\x8c\x18pandas.core.indexes.base\x94\x8c\n_new_Index\x94\x93\x94h\x94\x8c\x05Index\x94\x93\x94}\x94(\x8c\x04data\x94h2h5K\x00\x85\x94h7\x87\x94R\x94(K\x01K\x0f\x85\x94h?\x89]\x94(\x8c\tvendor_id\x94\x8c\x0fpickup_datetime\x94\x8c\x10dropoff_datetime\x94\x8c\x0fpassenger_count\x94\x8c\rtrip_distance\x94\x8c\x10pickup_longitude\x94\x8c\x0fpickup_latitude\x94\x8c\x11dropoff_longitude\x94\x8c\x10dropoff_latitude\x94\x8c\x0cpayment_type\x94\x8c\x0bfare_amount\x94\x8c\tsurcharge\x94\x8c\ntip_amount\x94\x8c\x0ctolls_amount\x94\x8c\x0ctotal_amount\x94et\x94b\x8c\x04name\x94Nu\x86\x94R\x94h\x96\x8c\x1bpandas.core.indexes.numeric\x94\x8c\nInt64Index\x94\x93\x94}\x94(h\x9ah2h5K\x00\x85\x94h7\x87\x94R\x94(K\x01K\x00\x85\x94hv\x89hdt\x94bh\xb0Nu\x86\x94R\x94e\x86\x94R\x94\x8c\x04_typ\x94\x8c\tdataframe\x94\x8c\t_metadata\x94]\x94\x8c\x05attrs\x94}\x94\x8c\x06_flags\x94}\x94\x8c\x17allows_duplicate_labels\x94\x88sub\x8c\x07columns\x94]\x94(h\xa0h\xa1h\xa2h\xa3h\xa4h\xa5h\xa6h\xa7h\xa8h\xa9 ...
# 0                Kingsbridge - Riverdale        101.0
# 1                        Northeast Bronx        102.0
# 2                   Fordham - Bronx Park        103.0
# 3                   Pelham - Throgs Neck        104.0
# 4                             Greenpoint        201.0
# 5            Downtown  - Heights - Slope        202.0
# 6     Bedford Stuyvesant - Crown Heights        203.0
# 7                          East New York        204.0
# 8                            Sunset Park        205.0
# 9                           Borough Park        206.0
# 10              East Flatbush - Flatbush        207.0
# 11                  Canarsie - Flatlands        208.0
# 12               Bensonhurst - Bay Ridge        209.0
# 13         Coney Island - Sheepshead Bay        210.0
# 14               Williamsburg - Bushwick        211.0
# 15           Washington Heights - Inwood        301.0
# 16  Central Harlem - Morningside Heights        302.0
# 17                           East Harlem        303.0
# 18                       Upper West Side        304.0
# 19            Long Island City - Astoria        401.0
# 20                           West Queens        402.0
# 21                  Flushing - Clearview        403.0
# 22              Ridgewood - Forest Hills        405.0
# 23                      Southwest Queens        407.0
# 24                               Jamaica        408.0
# 25                      Southeast Queens        409.0
# 26                              Rockaway        410.0
# 27            Upper East Side - Gramercy     305307.0
# 28                     Chelsea - Village     306308.0
# 29         Union Square, Lower Manhattan     309310.0
# 30                     Bayside - Meadows     404406.0
# 31                           Northern SI     501502.0
# 32                           Southern SI     503504.0
# 33                           South Bronx  105106107.0
#
#                                              geometry
# 0   POLYGON ((-73.87793 40.90556, -73.87859 40.903...
# 1   POLYGON ((-73.85253 40.90985, -73.85235 40.909...
# 2   POLYGON ((-73.85627 40.88315, -73.85666 40.882...
# 3   MULTIPOLYGON (((-73.81625 40.86082, -73.81584 ...
# 4   POLYGON ((-73.92436 40.71557, -73.92404 40.714...
# 5   POLYGON ((-73.97022 40.70673, -73.97018 40.704...
# 6   POLYGON ((-73.94506 40.68910, -73.94491 40.688...
# 7   POLYGON ((-73.86651 40.68447, -73.86630 40.683...
# 8   MULTIPOLYGON (((-73.99723 40.66921, -73.99687 ...
# 9   POLYGON ((-73.97379 40.65639, -73.97355 40.655...
# 10  POLYGON ((-73.96290 40.66380, -73.96243 40.663...
# 11  MULTIPOLYGON (((-73.89860 40.65583, -73.89800 ...
# 12  POLYGON ((-74.01695 40.63056, -74.01729 40.629...
# 13  POLYGON ((-73.93935 40.61019, -73.93754 40.608...
# 14  POLYGON ((-73.92633 40.71404, -73.92453 40.713...
# 15  MULTIPOLYGON (((-73.92255 40.87757, -73.92187 ...
# 16  POLYGON ((-73.93431 40.82431, -73.93409 40.820...
# 17  MULTIPOLYGON (((-73.93672 40.80822, -73.93511 ...
# 18  POLYGON ((-73.96485 40.80671, -73.96201 40.805...
# 19  POLYGON ((-73.90387 40.77891, -73.90347 40.778...
# 20  MULTIPOLYGON (((-73.88806 40.76831, -73.88773 ...
# 21  MULTIPOLYGON (((-73.81985 40.80089, -73.81307 ...
# 22  POLYGON ((-73.84418 40.73426, -73.84397 40.733...
# 23  MULTIPOLYGON (((-73.82574 40.71517, -73.82464 ...
# 24  MULTIPOLYGON (((-73.74925 40.70293, -73.74895 ...
# 25  POLYGON ((-73.71345 40.75961, -73.71331 40.759...
# 26  MULTIPOLYGON (((-73.76702 40.61422, -73.76520 ...
# 27  MULTIPOLYGON (((-73.96389 40.75209, -73.96717 ...
# 28  POLYGON ((-73.99334 40.77273, -73.99065 40.771...
# 29  MULTIPOLYGON (((-73.98977 40.73918, -73.98771 ...
# 30  POLYGON ((-73.73499 40.77303, -73.73399 40.772...
# 31  POLYGON ((-74.07793 40.64902, -74.07627 40.648...
# 32  MULTIPOLYGON (((-74.17855 40.62466, -74.17851 ...
# 33  POLYGON ((-73.91444 40.85978, -73.91328 40.859...  >}, 'dependencies': {"('from_pandas-5170b6dd4640c660eba8d74f671ed4e4', 0)": set()}}, 'annotations': {}}, {'__module__': 'dask.highlevelgraph', '__name__': 'MaterializedLayer', 'state': {'dsk': {"('sjoin-c2d35882e2de0ab2bf53039cd55f43e7', 0)": {'function': b'\x80\x04\x95#\x00\x00\x00\x00\x00\x00\x00\x8c\x15geopandas.tools.sjoin\x94\x8c\x05sjoin\x94\x93\x94.', 'args': b"\x80\x04\x95~\x00\x00\x00\x00\x00\x00\x00(\x8c0('_set_crs-6ca0659b532951365eb2f3c74d7d5dda', 0)\x94\x8c3('from_pandas-5170b6dd4640c660eba8d74f671ed4e4', 0)\x94\x8c\x05inner\x94\x8c\x06within\x94t\x94."}}, 'dependencies': {"('sjoin-c2d35882e2de0ab2bf53039cd55f43e7', 0)": {"('_set_crs-6ca0659b532951365eb2f3c74d7d5dda', 0)", "('from_pandas-5170b6dd4640c660eba8d74f671ed4e4', 0)"}}}, 'annotations': {}}, {'__module__': 'dask.highlevelgraph', '__name__': 'MaterializedLayer', 'state': {'dsk': {"('head-1-5-sjoin-c2d35882e2de0ab2bf53039cd55f43e7', 0)": {'function': b'\x80\x04\x95%\x00\x00\x00\x00\x00\x00\x00\x8c\x13dask.dataframe.core\x94\x8c\tsafe_head\x94\x93\x94.', 'args': b"\x80\x04\x955\x00\x00\x00\x00\x00\x00\x00\x8c-('sjoin-c2d35882e2de0ab2bf53039cd55f43e7', 0)\x94K\x05\x86\x94."}}, 'dependencies': {"('head-1-5-sjoin-c2d35882e2de0ab2bf53039cd55f43e7', 0)": {"('sjoin-c2d35882e2de0ab2bf53039cd55f43e7', 0)"}}}, 'annotations': {}}]}, 'keys': ["('head-1-5-sjoin-c2d35882e2de0ab2bf53039cd55f43e7', 0)"], 'priority': None, 'submitting_task': None, 'fifo_timeout': '60s', 'actors': None, 'code': 'joined1.head()\n'}]
# distributed.comm.utils - ERROR - can not serialize 'numpy.int64' object
# Traceback (most recent call last):
#   File "/Users/rpelgrim/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/distributed/comm/utils.py", line 33, in _to_frames
#     return list(protocol.dumps(msg, **kwargs))
#   File "/Users/rpelgrim/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/distributed/protocol/core.py", line 76, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#   File "/Users/rpelgrim/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/msgpack/__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#   File "msgpack/_packer.pyx", line 294, in msgpack._cmsgpack.Packer.pack
#   File "msgpack/_packer.pyx", line 300, in msgpack._cmsgpack.Packer.pack
#   File "msgpack/_packer.pyx", line 297, in msgpack._cmsgpack.Packer.pack
#   File "msgpack/_packer.pyx", line 264, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 231, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 231, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 264, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 231, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 231, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 231, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 264, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 264, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 291, in msgpack._cmsgpack.Packer._pack
# TypeError: can not serialize 'numpy.int64' object
# distributed.batched - ERROR - Error in batched write
# Traceback (most recent call last):
#   File "/Users/rpelgrim/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/distributed/batched.py", line 93, in _background_send
#     nbytes = yield self.comm.write(
#   File "/Users/rpelgrim/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/tornado/gen.py", line 762, in run
#     value = future.result()
#   File "/Users/rpelgrim/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/distributed/comm/tcp.py", line 249, in write
#     frames = await to_frames(
#   File "/Users/rpelgrim/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/distributed/comm/utils.py", line 50, in to_frames
#     return _to_frames()
#   File "/Users/rpelgrim/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/distributed/comm/utils.py", line 33, in _to_frames
#     return list(protocol.dumps(msg, **kwargs))
#   File "/Users/rpelgrim/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/distributed/protocol/core.py", line 76, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#   File "/Users/rpelgrim/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/msgpack/__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#   File "msgpack/_packer.pyx", line 294, in msgpack._cmsgpack.Packer.pack
#   File "msgpack/_packer.pyx", line 300, in msgpack._cmsgpack.Packer.pack
#   File "msgpack/_packer.pyx", line 297, in msgpack._cmsgpack.Packer.pack
#   File "msgpack/_packer.pyx", line 264, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 231, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 231, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 264, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 231, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 231, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 231, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 264, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 264, in msgpack._cmsgpack.Packer._pack
#   File "msgpack/_packer.pyx", line 291, in msgpack._cmsgpack.Packer._pack
# TypeError: can not serialize 'numpy.int64' object
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 joined1.head()
#
# File ~/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/dask/dataframe/core.py:1138, in _Frame.head(self, n, npartitions, compute)
#    1136 # No need to warn if we're already looking at all partitions
#    1137 safe = npartitions != self.npartitions
# -> 1138 return self._head(n=n, npartitions=npartitions, compute=compute, safe=safe)
#
# File ~/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/dask/dataframe/core.py:1172, in _Frame._head(self, n, npartitions, compute, safe)
#    1167 result = new_dd_object(
#    1168     graph, name, self._meta, [self.divisions[0], self.divisions[npartitions]]
#    1169 )
#    1171 if compute:
# -> 1172     result = result.compute()
#    1173 return result
#
# File ~/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/dask/base.py:288, in DaskMethodsMixin.compute(self, **kwargs)
#     264 def compute(self, **kwargs):
#     265     """Compute this dask collection
#     266
#     267     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     286     dask.base.compute
#     287     """
# --> 288     (result,) = compute(self, traverse=False, **kwargs)
#     289     return result
#
# File ~/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/dask/base.py:571, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     568     keys.append(x.__dask_keys__())
#     569     postcomputes.append(x.__dask_postcompute__())
# --> 571 results = schedule(dsk, keys, **kwargs)
#     572 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/distributed/client.py:2746, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2744         should_rejoin = False
#    2745 try:
# -> 2746     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2747 finally:
#    2748     for f in futures.values():
#
# File ~/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/distributed/client.py:1946, in Client.gather(self, futures, errors, direct, asynchronous)
#    1944 else:
#    1945     local_worker = None
# -> 1946 return self.sync(
#    1947     self._gather,
#    1948     futures,
#    1949     errors=errors,
#    1950     direct=direct,
#    1951     local_worker=local_worker,
#    1952     asynchronous=asynchronous,
#    1953 )
#
# File ~/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/distributed/utils.py:310, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     308     return future
#     309 else:
# --> 310     return sync(
#     311         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     312     )
#
# File ~/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/distributed/utils.py:364, in sync(loop, func, callback_timeout, *args, **kwargs)
#     362 if error[0]:
#     363     typ, exc, tb = error[0]
# --> 364     raise exc.with_traceback(tb)
#     365 else:
#     366     return result[0]
#
# File ~/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/distributed/utils.py:349, in sync.<locals>.f()
#     347     if callback_timeout is not None:
#     348         future = asyncio.wait_for(future, callback_timeout)
# --> 349     result[0] = yield future
#     350 except Exception:
#     351     error[0] = sys.exc_info()
#
# File ~/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/tornado/gen.py:762, in Runner.run(self)
#     759 exc_info = None
#     761 try:
# --> 762     value = future.result()
#     763 except Exception:
#     764     exc_info = sys.exc_info()
#
# File ~/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/distributed/client.py:1812, in Client._gather(self, futures, errors, direct, local_worker)
#    1810     else:
#    1811         raise exception.with_traceback(traceback)
# -> 1812     raise exc
#    1813 if errors == "skip":
#    1814     bad_keys.add(key)
#
# CancelledError: ('head-1-5-sjoin-c2d35882e2de0ab2bf53039cd55f43e7', 0)
# distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client
# ERROR:asyncio:_GatheringFuture exception was never retrieved
# future: <_GatheringFuture finished exception=CancelledError()>
# asyncio.exceptions.CancelledError
# distributed.deploy.cluster - WARNING - Failed to sync cluster info multiple times - perhaps there's a connection issue? Error:
# Traceback (most recent call last):
#   File "/Users/rpelgrim/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/distributed/comm/tcp.py", line 409, in connect
#     stream = await self.client.connect(
#   File "/Users/rpelgrim/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/rpelgrim/mambaforge/envs/dask-dataframe/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/rpelgrim/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/distributed/comm/core.py", line 289, in connect
#     comm = await asyncio.wait_for(
#   File "/Users/rpelgrim/mambaforge/envs/dask-dataframe/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/rpelgrim/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/distributed/deploy/cluster.py", line 131, in _sync_cluster_info
#     await self.scheduler_comm.set_metadata(
#   File "/Users/rpelgrim/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/distributed/core.py", line 822, in send_recv_from_rpc
#     comm = await self.live_comm()
#   File "/Users/rpelgrim/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/distributed/core.py", line 779, in live_comm
#     comm = await connect(
#   File "/Users/rpelgrim/mambaforge/envs/dask-dataframe/lib/python3.9/site-packages/distributed/comm/core.py", line 313, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tls://54.236.35.213:8786 after 30 s
