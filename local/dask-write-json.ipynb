# %%
import dask.dataframe as dd
import pandas as pd

# %%
df = pd.DataFrame({"col1": ["a", "b", "c", "d"], "col2": [1, 2, 3, 4]})

# %%
ddf = dd.from_pandas(df, npartitions=2)

# %%
ddf.to_json("../tmp/first-json")
# Out:
# ['/Users/powers/Documents/code/coiled/coiled-resources/tmp/first-json/0.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/first-json/1.part']

# %%
ddf.to_json("../tmp/json2", orient="split")
# Out:
# ['/Users/powers/Documents/code/coiled/coiled-resources/tmp/json2/0.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/json2/1.part']

# %%
def my_json_filenamer(file_num):
    return f"part-{file_num:04}-data"

# %%
ddf.to_json("../tmp/json3", name_function=my_json_filenamer)
# Out:
# ['/Users/powers/Documents/code/coiled/coiled-resources/tmp/json3/part-0000-data.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/json3/part-0001-data.part']

# %%
def my_csv_filenamer(file_num):
    return f"some-{file_num:04}-data.csv"

# %%
ddf.to_csv("../tmp/csv3", name_function=my_csv_filenamer)
# Out:
# ['/Users/powers/Documents/code/coiled/coiled-resources/tmp/csv3/some-0000-data.csv.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/csv3/some-0001-data.csv.part']

# %%
import dask

# %%
ddf = dask.datasets.timeseries(
    start="2015-01-01",
    end="2020-12-31",
    freq="1s",
    partition_freq="7d",
    seed=42,
)

# %%
len(ddf)
# Out:
# 189302400

# %%
ddf.npartitions
# Out:
# 313

# %%
ddf.to_json("../tmp/timeseries-json")
# Out:
# ['/Users/powers/Documents/code/coiled/coiled-resources/tmp/timeseries-json/000.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/timeseries-json/001.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/timeseries-json/002.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/timeseries-json/003.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/timeseries-json/004.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/timeseries-json/005.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/timeseries-json/006.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/timeseries-json/007.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/timeseries-json/008.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/timeseries-json/009.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/timeseries-json/010.part',
# ...

# %%
ddf.to_json("../tmp/timeseries-json-gzip", compression="gzip")
# Out:
# ['/Users/powers/Documents/code/coiled/coiled-resources/tmp/timeseries-json-gzip/000.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/timeseries-json-gzip/001.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/timeseries-json-gzip/002.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/timeseries-json-gzip/003.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/timeseries-json-gzip/004.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/timeseries-json-gzip/005.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/timeseries-json-gzip/006.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/timeseries-json-gzip/007.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/timeseries-json-gzip/008.part',
#  '/Users/powers/Documents/code/coiled/coiled-resources/tmp/timeseries-json-gzip/009.part',
# ...

# %%
ddf.to_csv("../tmp/timeseries-csv-gzip", compression="gzip")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [26], in <module>
# ----> 1 ddf.to_csv("../tmp/timeseries-csv-gzip", compression="gzip")
#
# File ~/opt/miniconda3/envs/standard-coiled/lib/python3.9/site-packages/dask/dataframe/core.py:1560, in _Frame.to_csv(self, filename, **kwargs)
#    1557 """See dd.to_csv docstring for more information"""
#    1558 from .io import to_csv
# -> 1560 return to_csv(self, filename, **kwargs)
#
# File ~/opt/miniconda3/envs/standard-coiled/lib/python3.9/site-packages/dask/dataframe/io/csv.py:957, in to_csv(df, filename, single_file, encoding, mode, name_function, compression, compute, scheduler, storage_options, header_first_partition_only, compute_kwargs, **kwargs)
#     953         compute_kwargs["scheduler"] = scheduler
#     955     import dask
# --> 957     return list(dask.compute(*values, **compute_kwargs))
#     958 else:
# ...
