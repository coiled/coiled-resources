# %%
import coiled

# %%
coiled.create_software_environment(
    name='streamlit',
    conda='/Users/rpelgrim/Documents/git/coiled-resources/streamlit-with-coiled/streamlit.yml',
    account='coiled-examples',
)
# Out:
# Creating new ecr build
# Creating new software environment
# STEP 1: FROM coiled/default:sha-6b4e896
# STEP 2: COPY environment.yml environment.yml
# --> b335eb8cd61
# STEP 3: RUN conda env update -n coiled -f environment.yml     && rm environment.yml     && conda clean --all -y     && echo "conda activate coiled" >> ~/.bashrc
# ...
# Solving environment: ...working... done
#
# ...
# zeromq-4.3.4         | 331 KB    | ########## | 100%
# lz4-3.1.3            | 42 KB     | ########## | 100%
# validators-0.18.2    | 18 KB     | ########## | 100%
# nbformat-5.1.3       | 44 KB     | ########## | 100%
# libboost-1.73.0      | 13.9 MB   | ########## | 100%
# tk-8.6.10            | 3.0 MB    | ########## | 100%
# libgfortran4-7.5.0   | 995 KB    | ########## | 100%
# olefile-0.46         | 33 KB     | ########## | 100%
# yarl-1.6.3           | 136 KB    | ########## | 100%
# bokeh-2.3.3          | 5.8 MB    | ########## | 100%
# krb5-1.19.2          | 1.2 MB    | ########## | 100%
# ...
