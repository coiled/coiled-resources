# %% [markdown]
# # Datashader with Dask
#
# Using Uber/Lyft NYC data preprocessed by Matt.

# %%
import dask.dataframe as dd

# %%
df = dd.read_parquet(
    "s3://coiled-datasets/dask-book/nyc-tlc/2009"
)

# %%
df.head()
# Out:
#   vendor_id     pickup_datetime    dropoff_datetime  passenger_count  \
# 0       VTS 2009-01-04 02:52:00 2009-01-04 03:02:00                1
# 1       VTS 2009-01-04 03:31:00 2009-01-04 03:38:00                3
# 2       VTS 2009-01-03 15:43:00 2009-01-03 15:57:00                5
# 3       DDS 2009-01-01 20:52:58 2009-01-01 21:14:00                1
# 4       DDS 2009-01-24 16:18:23 2009-01-24 16:24:56                1
#
#    trip_distance  pickup_longitude  pickup_latitude  rate_code  \
# 0           2.63        -73.991957        40.721567        NaN
# 1           4.55        -73.982102        40.736290        NaN
# 2          10.35        -74.002587        40.739748        NaN
# 3           5.00        -73.974267        40.790955        NaN
# 4           0.40        -74.001580        40.719382        NaN
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude payment_type  \
# 0               None         -73.993803         40.695922         CASH
# 1               None         -73.955850         40.768030       Credit
# 2               None         -73.869983         40.770225       Credit
# 3               None         -73.996558         40.731849       CREDIT
# 4               None         -74.008378         40.720350         CASH
#
#    fare_amount  surcharge  mta_tax  tip_amount  tolls_amount  total_amount
# 0          8.9        0.5      NaN        0.00           0.0          9.40
# 1         12.1        0.5      NaN        2.00           0.0         14.60
# 2         23.7        0.0      NaN        4.74           0.0         28.44
# 3         14.9        0.5      NaN        3.05           0.0         18.45
# 4          3.7        0.0      NaN        0.00           0.0          3.70

# %%
df = dd.read_parquet(
    "s3://oss-shared-scratch/mrocklin/nyc-taxi/"
)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/mambaforge/envs/crt/lib/python3.10/site-packages/s3fs/core.py:110, in _error_wrapper(func, args, kwargs, retries)
#     109 try:
# --> 110     return await func(*args, **kwargs)
#     111 except S3_RETRYABLE_ERRORS as e:
#
# File ~/mambaforge/envs/crt/lib/python3.10/site-packages/aiobotocore/client.py:265, in AioBaseClient._make_api_call(self, operation_name, api_params)
#     264     error_class = self.exceptions.from_code(error_code)
# --> 265     raise error_class(parsed_response, operation_name)
#     266 else:
#
# ClientError: An error occurred (AccessDenied) when calling the GetObject operation: Access Denied
#
# The above exception was the direct cause of the following exception:
#
# PermissionError                           Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 df = dd.read_parquet(
#       2     "s3://oss-shared-scratch/mrocklin/nyc-taxi/"
#       3 )
#
# File ~/mambaforge/envs/crt/lib/python3.10/site-packages/dask/dataframe/io/parquet/core.py:460, in read_parquet(path, columns, filters, categories, index, storage_options, engine, calculate_divisions, ignore_metadata_file, metadata_task_size, split_row_groups, chunksize, aggregate_files, parquet_file_extension, **kwargs)
#     457 if index and isinstance(index, str):
#     458     index = [index]
# --> 460 read_metadata_result = engine.read_metadata(
#     461     fs,
#     462     paths,
#     463     categories=categories,
#     464     index=index,
#     465     gather_statistics=calculate_divisions,
#     466     filters=filters,
#     467     split_row_groups=split_row_groups,
#     468     chunksize=chunksize,
#     469     aggregate_files=aggregate_files,
#     470     ignore_metadata_file=ignore_metadata_file,
#     471     metadata_task_size=metadata_task_size,
#     472     parquet_file_extension=parquet_file_extension,
#     473     **kwargs,
#     474 )
#     476 # In the future, we may want to give the engine the
#     477 # option to return a dedicated element for `common_kwargs`.
#     478 # However, to avoid breaking the API, we just embed this
#     479 # data in the first element of `parts` for now.
#     480 # The logic below is inteded to handle backward and forward
#     481 # compatibility with a user-defined engine.
#     482 meta, statistics, parts, index = read_metadata_result[:4]
#
# File ~/mambaforge/envs/crt/lib/python3.10/site-packages/dask/dataframe/io/parquet/arrow.py:341, in ArrowDatasetEngine.read_metadata(cls, fs, paths, categories, index, gather_statistics, filters, split_row_groups, chunksize, aggregate_files, ignore_metadata_file, metadata_task_size, parquet_file_extension, **kwargs)
#     322 @classmethod
#     323 def read_metadata(
#     324     cls,
#    (...)
#     339
#     340     # Stage 1: Collect general dataset information
# --> 341     dataset_info = cls._collect_dataset_info(
#     342         paths,
#     343         fs,
#     344         categories,
#     345         index,
#     346         gather_statistics,
#     347         filters,
#     348         split_row_groups,
#     349         chunksize,
#     350         aggregate_files,
#     351         ignore_metadata_file,
#     352         metadata_task_size,
#     353         parquet_file_extension,
#     354         kwargs,
#     355     )
#     357     # Stage 2: Generate output `meta`
#     358     meta = cls._create_dd_meta(dataset_info)
#
# File ~/mambaforge/envs/crt/lib/python3.10/site-packages/dask/dataframe/io/parquet/arrow.py:857, in ArrowDatasetEngine._collect_dataset_info(cls, paths, fs, categories, index, gather_statistics, filters, split_row_groups, chunksize, aggregate_files, ignore_metadata_file, metadata_task_size, parquet_file_extension, kwargs)
#     855 # Final "catch-all" pyarrow.dataset call
#     856 if ds is None:
# --> 857     ds = pa_ds.dataset(
#     858         paths,
#     859         filesystem=fs,
#     860         **_dataset_kwargs,
#     861     )
#     863 # Deal with directory partitioning
#     864 # Get all partition keys (without filters) to populate partition_obj
#     865 partition_obj = []  # See `partition_info` description below
#
# File ~/mambaforge/envs/crt/lib/python3.10/site-packages/pyarrow/dataset.py:697, in dataset(source, schema, format, filesystem, partitioning, partition_base_dir, exclude_invalid_files, ignore_prefixes)
#     695 elif isinstance(source, (tuple, list)):
#     696     if all(_is_path_like(elem) for elem in source):
# --> 697         return _filesystem_dataset(source, **kwargs)
#     698     elif all(isinstance(elem, Dataset) for elem in source):
#     699         return _union_dataset(source, **kwargs)
#
# File ~/mambaforge/envs/crt/lib/python3.10/site-packages/pyarrow/dataset.py:449, in _filesystem_dataset(source, schema, filesystem, partitioning, format, partition_base_dir, exclude_invalid_files, selector_ignore_prefixes)
#     441 options = FileSystemFactoryOptions(
#     442     partitioning=partitioning,
#     443     partition_base_dir=partition_base_dir,
#     444     exclude_invalid_files=exclude_invalid_files,
#     445     selector_ignore_prefixes=selector_ignore_prefixes
#     446 )
#     447 factory = FileSystemDatasetFactory(fs, paths_or_selector, format, options)
# --> 449 return factory.finish(schema)
#
# File ~/mambaforge/envs/crt/lib/python3.10/site-packages/pyarrow/_dataset.pyx:1857, in pyarrow._dataset.DatasetFactory.finish()
#
# File ~/mambaforge/envs/crt/lib/python3.10/site-packages/pyarrow/error.pxi:144, in pyarrow.lib.pyarrow_internal_check_status()
#
# File ~/mambaforge/envs/crt/lib/python3.10/site-packages/fsspec/spec.py:1578, in AbstractBufferedFile.read(self, length)
#    1575 if length == 0:
#    1576     # don't even bother calling fetch
#    1577     return b""
# -> 1578 out = self.cache._fetch(self.loc, self.loc + length)
#    1579 self.loc += len(out)
#    1580 return out
#
# File ~/mambaforge/envs/crt/lib/python3.10/site-packages/fsspec/caching.py:377, in BytesCache._fetch(self, start, end)
#     371     return b""
#     373 if (self.start is None or start < self.start) and (
#     374     self.end is None or end > self.end
#     375 ):
#     376     # First read, or extending both before and after
# --> 377     self.cache = self.fetcher(start, bend)
#     378     self.start = start
#     379 elif start < self.start:
#
# File ~/mambaforge/envs/crt/lib/python3.10/site-packages/s3fs/core.py:2030, in S3File._fetch_range(self, start, end)
#    2028 def _fetch_range(self, start, end):
#    2029     try:
# -> 2030         return _fetch_range(
#    2031             self.fs,
#    2032             self.bucket,
#    2033             self.key,
#    2034             self.version_id,
#    2035             start,
#    2036             end,
#    2037             req_kw=self.req_kw,
#    2038         )
#    2040     except OSError as ex:
#    2041         if ex.args[0] == errno.EINVAL and "pre-conditions" in ex.args[1]:
#
# File ~/mambaforge/envs/crt/lib/python3.10/site-packages/s3fs/core.py:2173, in _fetch_range(fs, bucket, key, version_id, start, end, req_kw)
#    2171     return b""
#    2172 logger.debug("Fetch: %s/%s, %s-%s", bucket, key, start, end)
# -> 2173 resp = fs.call_s3(
#    2174     "get_object",
#    2175     Bucket=bucket,
#    2176     Key=key,
#    2177     Range="bytes=%i-%i" % (start, end - 1),
#    2178     **version_id_kw(version_id),
#    2179     **req_kw,
#    2180 )
#    2181 return sync(fs.loop, resp["Body"].read)
#
# File ~/mambaforge/envs/crt/lib/python3.10/site-packages/fsspec/asyn.py:86, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#      83 @functools.wraps(func)
#      84 def wrapper(*args, **kwargs):
#      85     self = obj or args[0]
# ---> 86     return sync(self.loop, func, *args, **kwargs)
#
# File ~/mambaforge/envs/crt/lib/python3.10/site-packages/fsspec/asyn.py:66, in sync(loop, func, timeout, *args, **kwargs)
#      64     raise FSTimeoutError from return_result
#      65 elif isinstance(return_result, BaseException):
# ---> 66     raise return_result
#      67 else:
#      68     return return_result
#
# File ~/mambaforge/envs/crt/lib/python3.10/site-packages/fsspec/asyn.py:26, in _runner(event, coro, result, timeout)
#      24     coro = asyncio.wait_for(coro, timeout=timeout)
#      25 try:
# ---> 26     result[0] = await coro
#      27 except Exception as ex:
#      28     result[0] = ex
#
# File ~/mambaforge/envs/crt/lib/python3.10/site-packages/s3fs/core.py:332, in S3FileSystem._call_s3(self, method, *akwarglist, **kwargs)
#     330 logger.debug("CALL: %s - %s - %s", method.__name__, akwarglist, kw2)
#     331 additional_kwargs = self._get_s3_method_kwargs(method, *akwarglist, **kwargs)
# --> 332 return await _error_wrapper(
#     333     method, kwargs=additional_kwargs, retries=self.retries
#     334 )
#
# File ~/mambaforge/envs/crt/lib/python3.10/site-packages/s3fs/core.py:137, in _error_wrapper(func, args, kwargs, retries)
#     135         err = e
#     136 err = translate_boto_error(err)
# --> 137 raise err
#
# PermissionError: Access Denied

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined
